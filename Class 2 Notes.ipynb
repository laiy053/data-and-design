# %% [markdown]
# # **My Second Notebook**

# %%
import pandas as pd

# %%
df = pd.read_csv('data/Public_Recycling_Bins.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 6 columns):
# Borough           545 non-null object
# Site type         545 non-null object
# Park/Site Name    545 non-null object
# Address           540 non-null object
# Latitude          544 non-null float64
# Longitude         544 non-null float64
# dtypes: float64(2), object(4)
# memory usage: 25.6+ KB

# %%
df.head()
# Out:
#   Borough    Site type         Park/Site Name  \
# 0   Bronx  Subproperty         227th St. Plgd
# 1   Bronx  Subproperty    Allerton Ballfields
# 2   Bronx      Outdoor  Arthur Ave & E 187 St
# 3   Bronx     Outdoor         Barstow Mansion
# 4   Bronx  Subproperty     Bradley Playground
#
#                            Address   Latitude  Longitude
# 0       E 227 St/Bronx River Pkway  40.890849 -73.864224
# 1     Allerton Ave & Moshulu Pkway  40.848891 -73.877128
# 2              Arthur Ave & 187 St  40.855570 -73.887565
# 3  895 Shore Road, Pelham Bay Park  40.871864 -73.805549
# 4           2001-2017 Bronx Park E  40.851889 -73.868549

# %%
df2 = pd.read_csv('data/public-recycling-bins.csv')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 6 columns):
# Borough           545 non-null object
# Site type         545 non-null object
# Park/Site Name    545 non-null object
# Address           540 non-null object
# Latitude          544 non-null float64
# Longitude         544 non-null float64
# dtypes: float64(2), object(4)
# memory usage: 25.6+ KB

# %%
df2.tail()
# Out:
#            Borough Site type      Park/Site Name             Address  \
# 540  Staten Island    Indoor  West Brighton Pool  899 Henderson Ave
# 541  Staten Island  Outdoor     Willowbrook Park    Willowbrook Park
# 542  Staten Island  Outdoor     Willowbrook Park    Willowbrook Park
# 543  Staten Island  Outdoor         Wolfe's Pond        Wolfe's Pond
# 544  Staten Island  Outdoor         Wolfe's Pond        Wolfe's Pond
#
#       Latitude  Longitude
# 540  40.637121 -74.119287
# 541  40.603832 -74.158697
# 542  40.603828 -74.161250
# 543  40.517368 -74.190913
# 544  40.518652 -74.187310

# %%
df2['Borough'].value_counts()
# Out:
# Manhattan        184
# Queens           117
# Bronx            108
# Brooklyn          89
# Staten Island     42
# Brooklyn           5
# Name: Borough, dtype: int64

# %%
df2['Site type'].value_counts()
# Out:
# Outdoor        305
# Outdoor        112
# Indoor          55
# Greenthumb      44
# Subproperty     29
# Name: Site type, dtype: int64

# %%
df.groupby('Borough').count()
# Out:
#                Site type  Park/Site Name  Address  Latitude  Longitude
# Borough
# Bronx                108             108      107       108        108
# Brooklyn              89              89       89        89         89
# Brooklyn               5               5        5         5          5
# Manhattan            184             184      183       183        183
# Queens               117             117      116       117        117
# Staten Island         42              42       40        42         42

# %%
df['Borough'] == 'Bronx'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
#        ...
# 515    False
# 516    False
# 517    False
# 518    False
# 519    False
# 520    False
# 521    False
# 522    False
# 523    False
# 524    False
# 525    False
# 526    False
# 527    False
# 528    False
# 529    False
# 530    False
# 531    False
# 532    False
# 533    False
# 534    False
# 535    False
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# 541    False
# 542    False
# 543    False
# 544    False
# Name: Borough, Length: 545, dtype: bool

# %%
df[df['Borough'] == 'Bronx']
# Out:
#     Borough    Site type                               Park/Site Name  \
# 0     Bronx  Subproperty                               227th St. Plgd
# 1     Bronx  Subproperty                          Allerton Ballfields
# 2     Bronx      Outdoor                        Arthur Ave & E 187 St
# 3     Bronx     Outdoor                               Barstow Mansion
# 4     Bronx  Subproperty                           Bradley Playground
# 5     Bronx      Outdoor                      Bronx Botanical Gardens
# 6     Bronx      Outdoor                      Bronx Botanical Gardens
# 7     Bronx      Outdoor                      Bronx Botanical Gardens
# 8     Bronx      Outdoor                      Bronx Botanical Gardens
# 9     Bronx      Outdoor                      Bronx County Courthouse
# 10    Bronx      Outdoor                      Bronx County Courthouse
# 11    Bronx     Outdoor                                    Bronx Park
# ...

# %%
df[(df['Borough'] == 'Bronx') | (df['Borough'] == 'Manhattan')]
# Out:
#        Borough    Site type                      Park/Site Name  \
# 0        Bronx  Subproperty                      227th St. Plgd
# 1        Bronx  Subproperty                 Allerton Ballfields
# 2        Bronx      Outdoor               Arthur Ave & E 187 St
# 3        Bronx     Outdoor                      Barstow Mansion
# 4        Bronx  Subproperty                  Bradley Playground
# 5        Bronx      Outdoor             Bronx Botanical Gardens
# 6        Bronx      Outdoor             Bronx Botanical Gardens
# 7        Bronx      Outdoor             Bronx Botanical Gardens
# 8        Bronx      Outdoor             Bronx Botanical Gardens
# 9        Bronx      Outdoor             Bronx County Courthouse
# 10       Bronx      Outdoor             Bronx County Courthouse
# 11       Bronx     Outdoor                           Bronx Park
# 12       Bronx     Outdoor       Bronx Park Playground at Lydig
# 13       Bronx      Outdoor                           Bronx Zoo
# ...

# %%
df.describe()
# Out:
#          Latitude   Longitude
# count  544.000000  544.000000
# mean    40.737460  -73.937484
# std      0.082250    0.089999
# min     40.505646  -74.235477
# 25%     40.694341  -73.997056
# 50%     40.729002  -73.945462
# 75%     40.804353  -73.877504
# max     40.911295  -73.734291

# %%
df.describe
# Out:
# <bound method NDFrame.describe of            Borough    Site type                  Park/Site Name  \
# 0            Bronx  Subproperty                  227th St. Plgd
# 1            Bronx  Subproperty             Allerton Ballfields
# 2            Bronx      Outdoor           Arthur Ave & E 187 St
# 3            Bronx     Outdoor                  Barstow Mansion
# 4            Bronx  Subproperty              Bradley Playground
# 5            Bronx      Outdoor         Bronx Botanical Gardens
# 6            Bronx      Outdoor         Bronx Botanical Gardens
# 7            Bronx      Outdoor         Bronx Botanical Gardens
# 8            Bronx      Outdoor         Bronx Botanical Gardens
# 9            Bronx      Outdoor         Bronx County Courthouse
# 10           Bronx      Outdoor         Bronx County Courthouse
# 11           Bronx     Outdoor                       Bronx Park
# 12           Bronx     Outdoor   Bronx Park Playground at Lydig
# ...

# %%
df.iloc[32]
# Out:
# Borough                                                       Bronx
# Site type                                                Greenthumb
# Park/Site Name    Edith Community Garden (830 Elton Tenants Assoc.)
# Address                                           836 Elton Avenue
# Latitude                                                    40.8229
# Longitude                                                  -73.9127
# Name: 32, dtype: object

# %%
import numpy as np

# %%
df.iloc[32, 4]
